# %% [markdown]
# ## Lab 3: pandas
#
# #### Introduction
#
# We will examine a dataset containing characteristics of lego sets manufactured between 1961 and 2019 from the BRICKSET website. Variables in the dataset are described below.
#
# | VARIABLE             |      DESCRIPTION             |
# |:----------|:-------------|
# | ID |  set id |
# | Name |    name of set   |
# | Themegroup | themegroup of set |
# | Theme |  theme of set |
# | Subtheme |    subtheme of set   |
# | Year | year released |
# | Pieces |  number of pieces |
# | Minifig |    number of minifigs   |
# | Package | type of packaging |
# | Retail_Price |  recommended retail pri
#
#
#
# Load pandas to read in the data and save it as dataframe named lego.

# %%
import pandas as pd

lego = pd.read_csv('lego.csv')

lego.head(7)
lego.loc[lego.retail_price == 0, :].head(7)
# Out:
#            id             name     themegroup        theme  \
# 2266  40135-1      Angler Fish  Miscellaneous  Promotional
# 2269  40138-1  Christmas Train  Miscellaneous     Seasonal
# 2882  40094-1       Snowplough  Miscellaneous  Promotional
# 2883  40095-1    Micro Manager  Miscellaneous  Promotional
# 2884  40096-1      Spring Tree  Miscellaneous  Promotional
# 2885  40097-1       Helicopter  Miscellaneous  Promotional
# 2886  40098-1           Dragon  Miscellaneous  Promotional
#
#                       subtheme    year  pieces  minifigs  package  \
# 2266  Monthly Mini Model Build  2015.0    29.0         0  Polybag
# 2269                 Christmas  2015.0   233.0         0      Box
# 2882  Monthly Mini Model Build  2014.0    46.0         0  Polybag
# 2883  Monthly Mini Model Build  2014.0    50.0         0      NaN
# 2884  Monthly Mini Model Build  2014.0    62.0         0  Polybag
# 2885  Monthly Mini Model Build  2014.0    44.0         0  Polybag
# 2886  Monthly Mini Model Build  2014.0    43.0         0  Polybag
#
#       retail_price
# 2266           0.0
# 2269           0.0
# 2882           0.0
# 2883           0.0
# 2884           0.0
# 2885           0.0
# 2886           0.0

# %%
lego.shape
# Out:
# (12214, 10)

# %%
lego.sample(7) # shows random 7 values
# Out:
#             id                     name        themegroup             theme  \
# 7304    5862-1       Flower Fairy Party             Girls          Belville
# 9367    5875-1   Belville Hospital Ward             Girls          Belville
# 9312    2339-1                Basic Box        Pre-school             Duplo
# 518    41599-1             Wonder Woman          Licensed        BrickHeadz
# 11644    293-1                    Piano    Vintage themes         Homemaker
# 3678   70003-1  Eris' Eagle Interceptor  Action/Adventure  Legends of Chima
# 3562   44000-1                 FURNO XL      Construction      HERO Factory
#
#                      subtheme    year  pieces  minifigs    package  \
# 7304                      NaN  2003.0   161.0         2        NaN
# 9367                      NaN  1996.0    96.0         4        NaN
# 9312                      NaN  1996.0    49.0         0        NaN
# 518    DC Comics Super Heroes  2018.0   143.0         0        Box
# 11644                     NaN  1973.0   131.0         0        Box
# 3678                      NaN  2013.0   348.0         3        Box
# 3562                      NaN  2013.0   103.0         0  Foil pack
#
#        retail_price
# 7304          48.00
# 9367            NaN
# 9312            NaN
# 518            9.99
# 11644           NaN
# 3678          34.99
# 3562          19.99

# %%
lego.describe()
# Out:
#                year        pieces      minifigs  retail_price
# count  12213.000000  11125.000000  12214.000000   7849.000000
# mean    2003.202817    201.429124      1.381775     28.547607
# std       13.683488    382.014126      2.405519     41.036308
# min     1955.000000      0.000000      0.000000      0.000000
# 25%     1997.000000     25.000000      0.000000      6.000000
# 50%     2007.000000     70.000000      1.000000     14.990000
# 75%     2014.000000    223.000000      2.000000     34.990000
# max     2019.000000  10004.000000     36.000000    799.990000

# %% [markdown]
# #### Question 1:
# Some sets have missing information for retail_price or pieces or both. This could be because the sets are free (giveaways), they aren’t traditional lego sets (comic books, etc) or just because the information is missing. Filter the lego dataset based on the specifications below and save the result as lego. Hence, you will overwrite the original lego object. In addition, describe the implications of removing these sets.
#
# Your new lego (data frame) should have:
#
# • no missing pieces
#
# • only contain sets with a nonzero number of pieces
#
# • no missing retail_price
#
# • only contain sets with a nonzero retail_price
#
# • no missing year
#
# - Print out the shape of the dataframe after cleaning the dataset.

# %%
# no missing values
print(lego.shape)
lego2 = lego.dropna() # any row that has any missing values will be dropped, not the best solution
print(lego2.shape)

lego2 = lego2.loc[lego2.retail_price > 0, :] # keeps any row with retail price > 0, keep all columns :
print(lego2.shape)
print(lego2.describe())
# Out:
# (12214, 10)
# (4360, 10)
# (4277, 10)
#               year       pieces     minifigs  retail_price
# count  4277.000000  4277.000000  4277.000000   4277.000000
# mean   2008.243395   251.114099     2.110592     29.231814
# std       9.602551   433.553512     2.479037     41.633822
# min    1961.000000     1.000000     0.000000      0.500000
# 25%    2002.000000    38.000000     0.000000      4.990000
# 50%    2012.000000   109.000000     1.000000     14.990000
# 75%    2015.000000   305.000000     3.000000     38.500000
# max    2019.000000  7541.000000    28.000000    799.990000

# %% [markdown]
# #### Question 2:
# Arrange the dataset in descending order of retail_price and print the first three rows. Report in words the names of the three most expensive lego sets, their prices, and how many pieces each has.

# %%
lego2.sort_values(by = 'retail_price' , ascending = False).head(3) # false cuz descending
lego2.sort_values(by = 'retail_price' , ascending = False).tail(3) # last 3; most cheap

lego2.theme.unique() # to get all the themes

lego2.loc[lego2.theme == 'Harry Potter' , :].shape # show all rows that have theme harry potter, : all columns
lego2.loc[lego2.theme == 'Harry Potter' , :].sample(6)
lego2.loc[lego2.theme == 'Harry Potter' , ['name' , 'themegroup','theme' , 'subtheme']].sample(6) # specify columns 

################################################################################################################

lego2.sort_values(by = 'retail_price' , ascending = False).head(3) # false cuz descending
# Out:
#            id                                    name themegroup      theme  \
# 1434  75192-1                       Millennium Falcon   Licensed  Star Wars
# 5944  10179-1  Ultimate Collector's Millennium Falcon   Licensed  Star Wars
# 2065  75159-1                              Death Star   Licensed  Star Wars
#
#                        subtheme    year  pieces  minifigs package  \
# 1434  Ultimate Collector Series  2017.0  7541.0         8     Box
# 5944  Ultimate Collector Series  2007.0  5197.0         5     Box
# 2065  Ultimate Collector Series  2016.0  4016.0        27     Box
#
#       retail_price
# 1434        799.99
# 5944        499.99
# 2065        499.99

# %% [markdown]
# #### Question 3:
#
# It appears that the most expensive sets generally have more pieces. Create a new variable (column) price_per_piece, representing the price in dollars per piece for each of the sets. Save the result as lego2. Hence, you will overwrite the current lego object.

# %%
lego2['price_per_piece'] = lego2.retail_price / lego2. pieces # create new column called price_per_piece
lego2.sample(6)
# Out:
#            id                           name  themegroup         theme  \
# 3286  75049-1                    Snowspeeder    Licensed     Star Wars
# 7625   4592-1                    Red Monster      Racing        Racers
# 7992   4709-1                Hogwarts Castle    Licensed  Harry Potter
# 3392  10512-1           Jake's Treasure Hunt  Pre-school         Duplo
# 4386   9526-1             Palpatine's Arrest    Licensed     Star Wars
# 202   75224-1  Sith Infiltrator Microfighter    Licensed     Star Wars
#
#                              subtheme    year  pieces  minifigs package  \
# 3286                        Episode V  2014.0   278.0         3     Box
# 7625                     Drome Racers  2002.0    25.0         0     Box
# 7992              Philosopher's Stone  2001.0   682.0         9     Box
# 3392  Jake and the Never Land Pirates  2013.0    22.0         1     Box
# 4386                      Episode III  2012.0   645.0         6     Box
# 202                     MicroFighters  2019.0    92.0         1     Box
#
#       retail_price  price_per_piece
# 3286         29.99         0.107878
# 7625          4.00         0.160000
# 7992         90.00         0.131965
# 3392         14.99         0.681364
# 4386         89.99         0.139519
# 202           9.99         0.108587

# %% [markdown]
# #### Question 4:
#
# Arrange the lego2 dataset in descending order of price_per_piece and return only the columns: name, themegroup, theme, pieces, price_per_piece, and the first five rows. What do you notice about these sets?

# %%
sorted_lego = lego2.sort_values(by = 'price_per_piece', ascending = False) # by: which column u will sort
sorted_lego = sorted_lego.loc[:,['name', 'themegroup', 'theme', 'pieces', 'price_per_piece']]
sorted_lego.head(5) 
# subset -> loc
# : all rows, specific columns
# Out:
#                                        name themegroup            theme  \
# 5551               Rechargeable Battery Box  Technical  Power Functions
# 5553                     Transformer 10V DC  Technical  Power Functions
# 5616              Collectable Display Set 2   Licensed        Star Wars
# 8694                     Temperature Sensor  Technical       Mindstorms
# 7540  Robotics Invention System Upgrade Kit  Technical       Mindstorms
#
#       pieces  price_per_piece
# 5551     1.0           49.990
# 5553     1.0           29.990
# 5616     2.0           24.995
# 8694     1.0           24.000
# 7540     1.0           20.000

# %% [markdown]
# #### Question 5:
#
# What is the mean price_per_piece for the top 40 'Toy Story' sets in terms of price_per_piece?

# %%
sorted_lego.loc[sorted_lego.theme == 'Toy Story', :].head(40).price_per_piece.mean()
# Out:
# 0.16089862892544177

# %% [markdown]
# #### Question 6:
#
# What are the unique themes in the lego dataset?

# %%
lego2.theme.value_counts() # counts for each theme, how many sets we have
lego2['theme'].unique()
# Out:
# array(['Creator Expert', 'Toy Story', 'Duplo', 'Architecture',
#        'Minecraft', 'Ideas', 'City', 'BrickHeadz', 'Ninjago',
#        'The Lego Movie 2: The Second Part', 'Star Wars',
#        'Speed Champions', 'Jurassic World', 'Marvel Super Heroes',
#        'DC Comics Super Heroes', 'Classic', 'Juniors', 'Wizarding World',
#        'Creator', 'Miscellaneous', 'Seasonal', 'Promotional', 'Disney',
#        'Unikitty', 'Friends', 'The LEGO Ninjago Movie',
#        'Collectable Minifigures', 'Nexo Knights', 'The LEGO Batman Movie',
#        'Pirates of the Caribbean', 'Dimensions', 'Mixels', 'Bionicle',
#        'Legends of Chima', 'Education', 'Teenage Mutant Ninja Turtles',
#        'The LEGO Movie', 'The Hobbit', 'The Lord of the Rings', 'Space',
#        'Mindstorms', 'Games', 'Castle', 'Monster Fighters',
#        'Bricks and More', 'Cars', 'Harry Potter', 'Racers',
#        'Power Functions', 'Indiana Jones', 'Pirates', 'Factory',
#        'Exo-Force', 'Trains', 'Sports', 'Town', 'World City',
#        'Alpha Team', 'Spider-Man', 'Bulk Bricks', 'Explore',
#        'Adventurers', 'Studios', 'Western', 'Technic', 'Basic',
#        'Aquazone', 'Service Packs', 'Time Cruisers', 'Assorted', 'Books',
#        'Samsonite', 'LEGOLAND'], dtype=object)
